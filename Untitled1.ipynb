# %%
import pandas as pd
import numpy as np

# %%
Boston_S = pd.read_csv('tmp49hxkfzo.csv')
Boston_S.head()
# Out:
#     incident_num           shooting_date district shooting_type_v2  \
# 0  I152000196-00  2015-01-01 13:30:00+00      C11        Non-Fatal
# 1  I152000879-00  2015-01-04 01:58:00+00      E18        Non-Fatal
# 2  I152001014-00  2015-01-04 18:52:00+00       E5        Non-Fatal
# 3  I152002232-00  2015-01-08 22:45:00+00       B2        Non-Fatal
# 4  I152002233-00  2015-01-08 22:45:00+00       B2        Non-Fatal
#
#   victim_gender                victim_race  victim_ethnicity_NIBRS  \
# 0          Male  Black or African American  Not Hispanic or Latinx
# 1          Male  Black or African American  Not Hispanic or Latinx
# 2          Male  Black or African American  Not Hispanic or Latinx
# 3          Male  Black or African American  Not Hispanic or Latinx
# 4        Female  Black or African American  Not Hispanic or Latinx
#
#   multi_victim
# 0            f
# 1            f
# 2            f
# 3            t
# 4            t

# %%
Boston_S
# Out:
#        incident_num           shooting_date district shooting_type_v2  \
# 0     I152000196-00  2015-01-01 13:30:00+00      C11        Non-Fatal
# 1     I152000879-00  2015-01-04 01:58:00+00      E18        Non-Fatal
# 2     I152001014-00  2015-01-04 18:52:00+00       E5        Non-Fatal
# 3     I152002232-00  2015-01-08 22:45:00+00       B2        Non-Fatal
# 4     I152002233-00  2015-01-08 22:45:00+00       B2        Non-Fatal
# ...             ...                     ...      ...              ...
# 1823      232036239  2023-05-10 00:18:00+00       B2        Non-Fatal
# 1824      232036239  2023-05-10 00:18:00+00       B2        Non-Fatal
# 1825      232035550  2023-05-07 21:39:23+00       A1        Non-Fatal
# 1826      232037206  2023-05-13 03:32:00+00       C6        Non-Fatal
# 1827      232037392  2023-05-13 21:35:00+00      C11        Non-Fatal
#
#      victim_gender                victim_race  victim_ethnicity_NIBRS  \
# ...

# %%
Boston_S_D = Boston_S[Boston_S['district'] == 'C11']
Boston_S_D
# Out:
#        incident_num           shooting_date district shooting_type_v2  \
# 0     I152000196-00  2015-01-01 13:30:00+00      C11        Non-Fatal
# 7     I152003226-00  2015-01-12 23:58:00+00      C11        Non-Fatal
# 29    I152019839-00  2015-03-12 00:11:00+00      C11        Non-Fatal
# 44    I152026538-00  2015-04-01 20:29:00+00      C11        Non-Fatal
# 48    I152028582-00  2015-04-08 20:21:00+00      C11            Fatal
# ...             ...                     ...      ...              ...
# 1814      232032268  2023-04-26 22:04:00+00      C11        Non-Fatal
# 1817      232034509  2023-05-04 16:05:56+00      C11        Non-Fatal
# 1818      232034509  2023-05-04 16:09:00+00      C11        Non-Fatal
# 1822      232035584  2023-05-07 20:19:00+00      C11            Fatal
# 1827      232037392  2023-05-13 21:35:00+00      C11        Non-Fatal
#
#      victim_gender                victim_race  victim_ethnicity_NIBRS  \
# ...

# %%
Boston_S_D_MV = Boston_S_D[Boston_S_D['multi_victim']== 't']
Boston_S_D_MV
# Out:
#        incident_num           shooting_date district shooting_type_v2  \
# 48    I152028582-00  2015-04-08 20:21:00+00      C11            Fatal
# 49    I152028599-00  2015-04-08 20:20:00+00      C11        Non-Fatal
# 51    I152029808-00  2015-04-12 21:51:00+00      C11        Non-Fatal
# 52    I152029808-00  2015-04-12 21:51:00+00      C11        Non-Fatal
# 71    I152042681-00  2015-05-24 16:16:27+00      C11        Non-Fatal
# ...             ...                     ...      ...              ...
# 1751      222083762  2022-10-30 05:50:00+00      C11        Non-Fatal
# 1798      232014078  2023-02-21 19:36:33+00      C11            Fatal
# 1799      232014078  2023-02-21 19:36:59+00      C11        Non-Fatal
# 1817      232034509  2023-05-04 16:05:56+00      C11        Non-Fatal
# 1818      232034509  2023-05-04 16:09:00+00      C11        Non-Fatal
#
#      victim_gender                victim_race  victim_ethnicity_NIBRS  \
# ...
